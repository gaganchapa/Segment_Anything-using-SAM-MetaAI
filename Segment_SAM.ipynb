# %% [markdown]
# <a href="https://colab.research.google.com/github/gaganchapa/Segment_Anything-using-SAM-MetaAI/blob/main/Segment_SAM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Segment Anything using SAM
#
# https://github.com/facebookresearch/segment-anything#segment-anything
#
# try: https://segment-anything.com/demo

# %%
! pip install metaseg -q
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 56.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.5/97.5 KB 9.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.2/141.2 KB 15.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.9/105.9 KB 9.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 KB 9.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 KB 5.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.8/68.8 KB 9.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 KB 6.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 KB 12.1 MB/s eta 0:00:00
# ...

# %%
# !wget -O image.jpg  https://www.scotsman.com/webimg/b25lY21zOmRmYmExYzE4LTZhY2ItNDBkZS1iMTU1LWY4YTVlZWNmYTdkYzowOTcxZDZlOC00MDc1LTQzYzItOWEyOC00YjNlNzFiY2Y1YzI=.jpg?width=1200&enable=upscale
# Out:
# --2023-04-08 21:07:33--  https://www.scotsman.com/webimg/b25lY21zOmRmYmExYzE4LTZhY2ItNDBkZS1iMTU1LWY4YTVlZWNmYTdkYzowOTcxZDZlOC00MDc1LTQzYzItOWEyOC00YjNlNzFiY2Y1YzI=.jpg?width=1200
# Resolving www.scotsman.com (www.scotsman.com)... 104.18.12.228, 104.18.13.228, 2606:4700::6812:de4, ...
# Connecting to www.scotsman.com (www.scotsman.com)|104.18.12.228|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 80259 (78K) [image/jpeg]
# Saving to: ‘image.jpg’
#
# image.jpg           100%[===================>]  78.38K  --.-KB/s    in 0.007s
#
# 2023-04-08 21:07:34 (11.7 MB/s) - ‘image.jpg’ saved [80259/80259]

# %%
from IPython.display import Image
Image("image.jpg")

# %%
from metaseg import SegAutoMaskGenerator
# Out:
# ...
# vit_b model has been successfully downloaded and saved as 'vit_b.pth'.

# %%
autoseg_image = SegAutoMaskGenerator().save_image(
    source="image.jpg",
    model_type="vit_h",
    points_per_side=16, 
    points_per_batch=64
)
# Out:
# ...
# vit_h model has been successfully downloaded and saved as 'vit_h.pth'.

# %%
from IPython.display import Image
Image("output.jpg")
